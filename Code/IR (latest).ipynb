# %%
import os
from whoosh.index import create_in
from whoosh.writing import BufferedWriter, AsyncWriter
from whoosh.analysis import StandardAnalyzer, SimpleAnalyzer
from whoosh.fields import *
import xml.etree.ElementTree as ET
import lxml.etree
import numpy as np
import time
import concurrent

# %%
doc_type = {k: 1 for k in ['inproceedings', 'incollection', 'book', 'proceedings', 'article', '']}
features = {'title': ('title', 'booktitle'),
            'year': ('year'),
            'author': ('author', 'editor'),
            'publication_venue': ('publisher', 'series', 'school', 'journal')}

# %%
standard_analyzer = StandardAnalyzer()
simple_analyzer = SimpleAnalyzer()

# %%
# Define schema
schema = Schema(
    title=TEXT(analyzer=standard_analyzer, stored=True),
    author=TEXT(analyzer=simple_analyzer, stored=True),
    year=NUMERIC(stored=True),
    publication_venue = TEXT(analyzer=standard_analyzer, stored=True)
)

# %%
# Create index directory if not exists
if not os.path.exists("indexdir"):
    os.mkdir("indexdir")

# %%
# Create an index
ix = create_in("indexdir", schema=schema, indexname="dblp")

# %%
class Parser():
    def __init__(self):
        self.idx = 0
        # self.buffer = []
        self.instance = {k: list() for k in features.keys()}
        self.time = time.time()
        self.timing = list([0])
        self.percent = 0
        self.flag = False

    def parse(self, file = './dblp.xml', dtd = './dblp.dtd'):
        for (event, element) in lxml.etree.iterparse(file, dtd_validation=True, events=['end'], load_dtd=dtd):
            if self.idx == 0:
                writer = AsyncWriter(ix, writerargs={'procs':6})
            if element.tag in doc_type:
                children = element.getchildren()
                self.idx += 1
                for child in children:
                    if child.tag in features['title']:
                        if child.text:
                            self.instance['title'].append(child.text)
                            self.flag = True
                    elif child.tag in features['author']:
                       if child.text:
                            self.instance['author'].append(child.text)
                            self.flag = True
                    elif child.tag in features['year']:
                        if child.text:
                            self.instance['year'].append(child.text)
                            self.flag = True
                    elif child.tag in features['publication_venue']:
                        if child.text:
                            self.instance['publication_venue'].append(child.text)
                            self.flag = True
            if self.flag:
                # print(self.idx)
                title = ', '.join(self.instance['title'])
                author = ', '.join(self.instance['author'])
                if self.instance['year'] == []:
                    self.instance['year'] = ['0']
                year = ', '.join(self.instance['year'])
                # print(self.instance)
                publication_venue = ', '.join(self.instance['publication_venue'])

                writer.add_document(title=title,
                                author=author,
                                year=year,
                                publication_venue=publication_venue)
                self.instance = {k: list() for k in features.keys()}
                self.flag = False
                if self.idx == 67867 or (element.tag == 'dblp' and event == 'end'):
                    self.percent += 1
                    self.timing.append(time.time() - self.time)
                    print(f"-- Finish indexing {self.percent}% of the corpus in {self.timing[-1]} seconds")
                    self.idx = 0
                    writer.commit(optimize=True)
        self.timing.append(time.time() - self.time)
        print(f"-- Finish indexing the corpus in {self.timing[-1]} seconds")
            # if self.flag:
            #     self.buffer.append(self.instance)
            #     self.instance = {k: list() for k in features.keys()}
            #     self.flag = False
            # if self.idx == 67866 or (element.tag == 'dblp' and event == 'end'):
            #     self.percent += 1
            #     ## idexing here
            #     for doc in self.buffer:
            #         # Handle None values in the fields
            #         title = ', '.join(doc['title'])
            #         author= ', '.join(doc['author'])
                    
            #         if doc['year'] == []:
            #             doc['year'] = ['0']
            #         year = ', '.join(doc['year'])
            #         publication_venue = ', '.join(doc['publication_venue'])
                    # if title == "":
                    #     print(doc)
                    # elif author == "":
                    #     print(doc)
                    # elif year == "":
                    #     print(doc)
                    # elif publication_venue == "":
                    #     print(doc)
                    # Add the document to the writer
                #     writer.add_document(title=title,
                #                 author=author,
                #                 year=year,
                #                 publication_venue=publication_venue)
                # if self.percent % 10 == 0 or (element.tag == 'dblp' and event == 'end'):
                #     self.timing.append(time.time() - self.time)
                #     print(f"-- Finish indexing {self.percent}% of the corpus in {self.timing[-1]} seconds")
                # self.idx = 0
                # self.buffer.clear()
       #writer.close()

# %%
timing = []
parser = Parser()
parser.parse()
# Out:
# -- Finish indexing 1% of the corpus in 6.990043878555298 seconds
# -- Finish indexing 2% of the corpus in 22.50542950630188 seconds
# -- Finish indexing 3% of the corpus in 39.62352395057678 seconds
# -- Finish indexing 4% of the corpus in 61.91430354118347 seconds
# -- Finish indexing 5% of the corpus in 99.30147504806519 seconds
# -- Finish indexing 6% of the corpus in 138.27858352661133 seconds
# -- Finish indexing 7% of the corpus in 155.332261800766 seconds
# -- Finish indexing 8% of the corpus in 171.87531924247742 seconds
# -- Finish indexing 9% of the corpus in 190.29377794265747 seconds
# -- Finish indexing 10% of the corpus in 210.10067009925842 seconds
# -- Finish indexing 11% of the corpus in 229.2938461303711 seconds
# -- Finish indexing 12% of the corpus in 247.00334358215332 seconds
# -- Finish indexing 13% of the corpus in 279.2983179092407 seconds
# -- Finish indexing 14% of the corpus in 313.4430034160614 seconds
# -- Finish indexing 15% of the corpus in 382.60352873802185 seconds
# -- Finish indexing 16% of the corpus in 421.2620897293091 seconds
# -- Finish indexing 17% of the corpus in 486.626752614975 seconds
# -- Finish indexing 18% of the corpus in 575.6895170211792 seconds
# -- Finish indexing 19% of the corpus in 602.4746425151825 seconds
# -- Finish indexing 20% of the corpus in 618.2597999572754 seconds
# -- Finish indexing 21% of the corpus in 644.5501201152802 seconds
# -- Finish indexing 22% of the corpus in 663.8205938339233 seconds
# -- Finish indexing 23% of the corpus in 683.5851857662201 seconds
# -- Finish indexing 24% of the corpus in 701.2400908470154 seconds
# -- Finish indexing 25% of the corpus in 718.470047712326 seconds
# -- Finish indexing 26% of the corpus in 735.1207728385925 seconds
# -- Finish indexing 27% of the corpus in 747.9142725467682 seconds
# -- Finish indexing 28% of the corpus in 761.6108713150024 seconds
# -- Finish indexing 29% of the corpus in 780.0628168582916 seconds
# -- Finish indexing 30% of the corpus in 797.8453011512756 seconds
# -- Finish indexing 31% of the corpus in 817.7593321800232 seconds
# -- Finish indexing 32% of the corpus in 837.38325548172 seconds
# -- Finish indexing 33% of the corpus in 855.0401067733765 seconds
# -- Finish indexing 34% of the corpus in 871.1948263645172 seconds
# -- Finish indexing 35% of the corpus in 886.4014031887054 seconds
# -- Finish indexing 36% of the corpus in 903.1699538230896 seconds
# -- Finish indexing 37% of the corpus in 925.0589678287506 seconds
# -- Finish indexing 38% of the corpus in 959.3089349269867 seconds
# -- Finish indexing 39% of the corpus in 996.9303665161133 seconds
# -- Finish indexing 40% of the corpus in 1020.4668910503387 seconds
# -- Finish indexing 41% of the corpus in 1043.2822897434235 seconds
# -- Finish indexing 42% of the corpus in 1067.8061769008636 seconds
# -- Finish indexing 43% of the corpus in 1197.7281892299652 seconds
# -- Finish indexing 44% of the corpus in 1223.6834907531738 seconds
# -- Finish indexing 45% of the corpus in 1254.6808531284332 seconds
# -- Finish indexing 46% of the corpus in 1312.1845881938934 seconds
# -- Finish indexing 47% of the corpus in 1374.669630765915 seconds
# -- Finish indexing 48% of the corpus in 1459.8497035503387 seconds
# -- Finish indexing 49% of the corpus in 1512.3704731464386 seconds
# -- Finish indexing 50% of the corpus in 1551.4952018260956 seconds
# -- Finish indexing 51% of the corpus in 1740.4946901798248 seconds
# -- Finish indexing 52% of the corpus in 1752.5471522808075 seconds
# -- Finish indexing 53% of the corpus in 1765.6209592819214 seconds
# -- Finish indexing 54% of the corpus in 1777.3456099033356 seconds
# -- Finish indexing 55% of the corpus in 1790.2499248981476 seconds
# -- Finish indexing 56% of the corpus in 1803.9901525974274 seconds
# -- Finish indexing 57% of the corpus in 1817.2952523231506 seconds
# -- Finish indexing 58% of the corpus in 1831.7188348770142 seconds
# -- Finish indexing 59% of the corpus in 1844.020281791687 seconds
# -- Finish indexing 60% of the corpus in 1857.0650081634521 seconds
# -- Finish indexing 61% of the corpus in 1870.6506736278534 seconds
# -- Finish indexing 62% of the corpus in 1883.4365329742432 seconds
# -- Finish indexing 63% of the corpus in 1903.8904383182526 seconds
# -- Finish indexing 64% of the corpus in 1928.5958893299103 seconds
# -- Finish indexing 65% of the corpus in 1975.8906755447388 seconds
# -- Finish indexing 66% of the corpus in 2041.5913009643555 seconds
# -- Finish indexing 67% of the corpus in 2088.016480445862 seconds
# -- Finish indexing 68% of the corpus in 2146.3647286891937 seconds
# -- Finish indexing 69% of the corpus in 2189.199901342392 seconds
# -- Finish indexing 70% of the corpus in 2236.812224149704 seconds
# -- Finish indexing 71% of the corpus in 2402.8417987823486 seconds
# -- Finish indexing 72% of the corpus in 2462.1533567905426 seconds
# -- Finish indexing 73% of the corpus in 2529.480728626251 seconds
# -- Finish indexing 74% of the corpus in 2605.5753333568573 seconds
# -- Finish indexing 75% of the corpus in 2688.954052209854 seconds
# -- Finish indexing 76% of the corpus in 2794.2123160362244 seconds
# -- Finish indexing 77% of the corpus in 2889.65318107605 seconds
# -- Finish indexing 78% of the corpus in 2911.696411371231 seconds
# -- Finish indexing 79% of the corpus in 2923.913991689682 seconds
# -- Finish indexing 80% of the corpus in 2936.261416912079 seconds
# -- Finish indexing 81% of the corpus in 2948.037543773651 seconds
# -- Finish indexing 82% of the corpus in 2960.7367436885834 seconds
# -- Finish indexing 83% of the corpus in 2972.995277404785 seconds
# -- Finish indexing 84% of the corpus in 2986.8618381023407 seconds
# -- Finish indexing 85% of the corpus in 3000.733905315399 seconds
# -- Finish indexing 86% of the corpus in 3013.719313621521 seconds
# -- Finish indexing 87% of the corpus in 3026.855924844742 seconds
# -- Finish indexing 88% of the corpus in 3038.386290550232 seconds
# -- Finish indexing 89% of the corpus in 3054.4641177654266 seconds
# -- Finish indexing 90% of the corpus in 3068.2040343284607 seconds
# -- Finish indexing 91% of the corpus in 3079.9125180244446 seconds
# -- Finish indexing 92% of the corpus in 3091.5899665355682 seconds
# -- Finish indexing 93% of the corpus in 3103.5895671844482 seconds
# -- Finish indexing 94% of the corpus in 3115.9714682102203 seconds
# -- Finish indexing 95% of the corpus in 3128.873635530472 seconds
# -- Finish indexing 96% of the corpus in 3143.146078109741 seconds
# -- Finish indexing 97% of the corpus in 3154.5150570869446 seconds
# -- Finish indexing 98% of the corpus in 3165.9270062446594 seconds
# -- Finish indexing 99% of the corpus in 3177.639685869217 seconds
# -- Finish indexing the corpus in 3498.3262786865234 seconds
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\alfre\OneDrive - Nanyang Technological University (1)\MSAI\AI6122 Text Data Management & Processing\Assignments\Group Project\IR (latest).ipynb Cell 8 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/alfre/OneDrive%20-%20Nanyang%20Technological%20University%20%281%29/MSAI/AI6122%20Text%20Data%20Management%20%26%20Processing/Assignments/Group%20Project/IR%20%28latest%29.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> timing = []
#       <a href='vscode-notebook-cell:/c%3A/Users/alfre/OneDrive%20-%20Nanyang%20Technological%20University%20%281%29/MSAI/AI6122%20Text%20Data%20Management%20%26%20Processing/Assignments/Group%20Project/IR%20%28latest%29.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> parser = Parser()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/alfre/OneDrive%20-%20Nanyang%20Technological%20University%20%281%29/MSAI/AI6122%20Text%20Data%20Management%20%26%20Processing/Assignments/Group%20Project/IR%20%28latest%29.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> parser.parse()
#
# c:\Users\alfre\OneDrive - Nanyang Technological University (1)\MSAI\AI6122 Text Data Management & Processing\Assignments\Group Project\IR (latest).ipynb Cell 8 line 9
#      <a href='vscode-notebook-cell:/c%3A/Users/alfre/OneDrive%20-%20Nanyang%20Technological%20University%20%281%29/MSAI/AI6122%20Text%20Data%20Management%20%26%20Processing/Assignments/Group%20Project/IR%20%28latest%29.ipynb#X10sZmlsZQ%3D%3D?line=57'>58</a> print(f"-- Finish indexing the corpus in {self.timing[-1]} seconds")
#      <a href='vscode-notebook-cell:/c%3A/Users/alfre/OneDrive%20-%20Nanyang%20Technological%20University%20%281%29/MSAI/AI6122%20Text%20Data%20Management%20%26%20Processing/Assignments/Group%20Project/IR%20%28latest%29.ipynb#X10sZmlsZQ%3D%3D?line=58'>59</a>     # if self.flag:
#      <a href='vscode-notebook-cell:/c%3A/Users/alfre/OneDrive%20-%20Nanyang%20Technological%20University%20%281%29/MSAI/AI6122%20Text%20Data%20Management%20%26%20Processing/Assignments/Group%20Project/IR%20%28latest%29.ipynb#X10sZmlsZQ%3D%3D?line=59'>60</a>     #     self.buffer.append(self.instance)
#      <a href='vscode-notebook-cell:/c%3A/Users/alfre/OneDrive%20-%20Nanyang%20Technological%20University%20%281%29/MSAI/AI6122%20Text%20Data%20Management%20%26%20Processing/Assignments/Group%20Project/IR%20%28latest%29.ipynb#X10sZmlsZQ%3D%3D?line=60'>61</a>     #     self.instance = {k: list() for k in features.keys()}
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/alfre/OneDrive%20-%20Nanyang%20Technological%20University%20%281%29/MSAI/AI6122%20Text%20Data%20Management%20%26%20Processing/Assignments/Group%20Project/IR%20%28latest%29.ipynb#X10sZmlsZQ%3D%3D?line=90'>91</a>         # self.idx = 0
#      <a href='vscode-notebook-cell:/c%3A/Users/alfre/OneDrive%20-%20Nanyang%20Technological%20University%20%281%29/MSAI/AI6122%20Text%20Data%20Management%20%26%20Processing/Assignments/Group%20Project/IR%20%28latest%29.ipynb#X10sZmlsZQ%3D%3D?line=91'>92</a>         # self.buffer.clear()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/alfre/OneDrive%20-%20Nanyang%20Technological%20University%20%281%29/MSAI/AI6122%20Text%20Data%20Management%20%26%20Processing/Assignments/Group%20Project/IR%20%28latest%29.ipynb#X10sZmlsZQ%3D%3D?line=92'>93</a> writer.close()
#
# AttributeError: 'AsyncWriter' object has no attribute 'close'
